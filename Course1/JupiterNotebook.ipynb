# %% [markdown]
# # Data Science Tools and Ecosystem

# %% [markdown]
# ### In this notebook, Data Science Tools and Ecosystem are summarized.

# %% [markdown]
# **Objectives:**
# -  List popular languages for Data Science
# -  List some data science libraries
# -  Indicate tools used in Data Science

# %% [markdown]
# Some of the **popular languages** that Data Scientits use are:
# 1. Python
# 2. R
# 3. SQL

# %% [markdown]
# Some of the **commoly used libraries** used by Data Scientists include:
# - Scientific computing
#    - Pandas
#    - Numpy
# - Visualization
#    - Matplotlib
#    - Seaborn
# - High level machine learning and deep learning
#    - Scikit-learn
#    - Keras
# - Deep learning
#    - TensorFlow
#    - Pytorch

# %% [markdown]
# Data Science Tools |
# ---|
# Jupyter Lab |
# R Studio |
# Apache Zeppelin |

# %% [markdown]
# ### Below are a few examples of evaluating arithmetic expressesions in Python
#
# ` 2 + 3 `   *addition*
#
# ` 10 - 5 `  *subtraction*
#
# ` 4 * 7 `   *multiplication*
#
# ` 9 / 3 `   *division*
#
# `2 ** 5 `   *exponentiation*
#
# `11 % 2`    *module*

# %%
( 3 * 4 ) + 5
# This is a simple arithmetic expression to multiply then add intergers
# Out:
# 17

# %% [markdown]
# ### Convert minutes to hours:

# %%
m = 200 / 60 # This expression will divide the 200 minutes by 60 (hour)
print(m) # This line will make the result appear on the screen
# Out:
# 3.3333333333333335

# %% [markdown]
# ## Author
# Silvia Moitinho
